# %% [markdown]
# <a href="https://colab.research.google.com/github/Shimaliza/self-project/blob/main/Cambodia_Tour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scraping data
#
#
# url: https://www.cambodia-service.com/

# %%
import requests

# %%
import os 
from PIL import Image
from IPython.display import IFrame
import pandas as pd
import numpy as np

# %%
url ="https://www.cambodia-service.com/"
r=requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.27.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
print(r.request.body)
# Out:
# None

# %%
header=r.headers
print(header)
# Out:
# {'Date': 'Tue, 28 Mar 2023 08:08:56 GMT', 'Server': 'Apache', 'Expires': 'Tue, 28 Mar 2023 09:08:57 GMT', 'Cache-Control': 'public, max-age=3600, public', 'Set-Cookie': 'CMSSESSID9dbd39dc9953=dbutqaahb2nh92g87vqgdoqe46; path=/', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Length': '16397', 'Keep-Alive': 'timeout=5, max=200', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=utf-8'}

# %%
arr=np.array(header)
arr
# Out:
# array(['Date', 'Server', 'Expires', 'Cache-Control', 'Set-Cookie', 'Vary',
#        'Content-Encoding', 'X-Frame-Options', 'Content-Length',
#        'Keep-Alive', 'Connection', 'Content-Type'], dtype='<U16')

# %%
header["date"]
# Out:
# 'Tue, 28 Mar 2023 08:08:56 GMT'

# %%
header["server"]
# Out:
# 'Apache'

# %%
header["X-Frame-Options"]
# Out:
# 'SAMEORIGIN'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text[0:100]
# Out:
# '\t<!doctype html><html lang="en_US"><head><title>Cambodia Service - Professional Travel Guides for Ex'

# %% [markdown]
# Scraping picture

# %%
url1="https://www.cambodia-service.com/uploads/images/blog-image/tour-package/poipet_cambodia_thailand_border.JPG"

# %%
r=requests.get(url1)

# %%
print(r.headers)
# Out:
# {'Date': 'Tue, 28 Mar 2023 08:16:49 GMT', 'Server': 'Apache', 'Accept-Ranges': 'bytes', 'Cache-Control': 'public', 'Expires': 'Thu, 27 Apr 2023 08:16:49 GMT', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Length': '49829', 'Keep-Alive': 'timeout=5, max=200', 'Connection': 'Keep-Alive', 'Content-Type': 'image/jpeg'}

# %%
r.headers['Content-Type']
# Out:
# 'image/jpeg'

# %%
path=os.path.join(os.getcwd(),'Shared Group Tours')
path
# Out:
# '/content/Shared Group Tours'

# %%
with open(path,'wb') as f:
    f.write(r.content)

# %%
Image.open(path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x344 at 0x7F4298CD6940>
