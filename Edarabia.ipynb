# %% [markdown]
# <a href="https://colab.research.google.com/github/Shimaliza/self-project/blob/main/Edarabia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scraping data
#
# Site content is about university and education opportunities around the world.
#
# URL https://www.edarabia.com/universities/izmir/

# %%
import requests

# %%
import os 
from PIL import Image
from IPython.display import IFrame
import pandas as pd
import numpy as np

# %%
url ="https://www.edarabia.com/universities/izmir/"
r=requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.27.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
print(r.request.body)
# Out:
# None

# %%
header=r.headers
print(header)
# Out:
# {'Date': 'Tue, 28 Mar 2023 08:27:47 GMT', 'Cache-Control': 'no-store, no-cache, must-revalidate', 'Content-Encoding': 'gzip', 'Transfer-Encoding': 'chunked', 'Content-Type': 'text/html; charset=UTF-8', 'Set-Cookie': 'SPSI=7cffd364128d4ae2a18417eb08054341; path=/; HttpOnly; SameSite=Lax;, SPSE=psUn9bnXEl5CAcFsgkGtz8Le/323/VCMxrFsoXZskEsnecEmeFK/LY+2xuQD2lEo1SCdWmdFYO24sc5zc5lrZA==; path=/; HttpOnly; SameSite=Lax;, spcsrf=4b030e82e0490812fe36a5bc8847e4b9; path=/; SameSite=Strict; HttpOnly;  expires=Tue, 28-Mar-23 10:27:46 GMT, adOtr=obsvl; path=/; SameSite=Lax; expires=Thu, 2 Aug 2001 20:47:11 UTC, UTGv2=D-h4610992b51e207465d29828ec5ac786eb50; path=/; SameSite=Lax; expires=Sun, 24-Sep-23 08:27:46 GMT, sp_lit=YmkJcYImm7M9S6OXNIv+1Q==; path=/; SameSite=Strict; HttpOnly; expires=Tue, 28-Mar-23 08:32:47 GMT', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Pragma': 'no-cache', 'Link': '<https://www.edarabia.com/wp-json/>; rel="https://api.w.org/"', 'ETag': 'W/"19784516-1679570670;gz"', 'X-Lit
# ...

# %%
arr=np.array(header)
arr
# Out:
# array(['Date', 'Cache-Control', 'Content-Encoding', 'Transfer-Encoding',
#        'Content-Type', 'Set-Cookie', 'Expires', 'Pragma', 'Link', 'ETag',
#        'X-LiteSpeed-Cache', 'Vary', 'Strict-Transport-Security',
#        'Alt-Svc', 'Server', 'X-HW', 'Access-Control-Allow-Origin',
#        'Connection'], dtype='<U27')

# %%
header["Server"]
# Out:
# 'fbs'

# %%
r.encoding
# Out:
# 'UTF-8'

# %%
r.text[0:500]
# Out:
# '<!DOCTYPE html><html lang="en-US" class="no-js"><head><meta charset="UTF-8"><link rel="preconnect" href="https://fonts.gstatic.com/" crossorigin /><script>WebFontConfig={google:{families:["Libre Baskerville","Roboto:400,700","Sintony:400,700&display=swap"]}};if ( typeof WebFont === "object" && typeof WebFont.load === "function" ) { WebFont.load( WebFontConfig ); }</script><script data-optimized="1" src="https://www.edarabia.com/wp-content/plugins/litespeed-cache/assets/js/webfontloader.min.js"><'

# %% [markdown]
# Picture Scraping

# %%
url1="https://tpc.googlesyndication.com/simgad/7087595963161681042?sqp=4sqPyQQ7QjkqNxABHQAAtEIgASgBMAk4A0DwkwlYAWBfcAKAAQGIAQGdAQAAgD-oAQGwAYCt4gS4AV_FAS2ynT4&rs=AOga4qnl-D4NZ26NESIBB6o-QjONr49vWw"

# %%
r=requests.get(url1)

# %%
print(r.headers)
# Out:
# {'Accept-Ranges': 'bytes', 'Content-Type': 'image/jpeg', 'Access-Control-Allow-Origin': '*', 'Cross-Origin-Resource-Policy': 'cross-origin', 'Cross-Origin-Opener-Policy-Report-Only': 'same-origin; report-to="content-ads-owners"', 'Report-To': '{"group":"content-ads-owners","max_age":2592000,"endpoints":[{"url":"https://csp.withgoogle.com/csp/report-to/content-ads-owners"}]}', 'Timing-Allow-Origin': '*', 'Content-Length': '50925', 'Date': 'Tue, 28 Mar 2023 08:37:50 GMT', 'Expires': 'Wed, 27 Mar 2024 08:37:50 GMT', 'Cache-Control': 'public, max-age=31536000', 'Last-Modified': 'Tue, 24 Jan 2023 15:41:25 GMT', 'X-Content-Type-Options': 'nosniff', 'Server': 'sffe', 'X-XSS-Protection': '0'}

# %%
pic_header=r.headers
arr=np.array(pic_header)
arr
# Out:
# array(['Accept-Ranges', 'Content-Type', 'Access-Control-Allow-Origin',
#        'Cross-Origin-Resource-Policy',
#        'Cross-Origin-Opener-Policy-Report-Only', 'Report-To',
#        'Timing-Allow-Origin', 'Content-Length', 'Date', 'Expires',
#        'Cache-Control', 'Last-Modified', 'X-Content-Type-Options',
#        'Server', 'X-XSS-Protection'], dtype='<U38')

# %%
pic_header["Timing-Allow-Origin"]
# Out:
# '*'

# %%
path=os.path.join(os.getcwd(),"Masaryk University")
path
# Out:
# '/content/Masaryk University'

# %%
with open(path,'wb') as f:
    f.write(r.content)

# %%
Image.open(path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x250 at 0x7FF0C66B5880>
