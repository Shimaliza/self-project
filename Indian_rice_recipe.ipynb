# %% [markdown]
# <a href="https://colab.research.google.com/github/Shimaliza/self-project/blob/main/Indian_rice_recipe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scraping data
#
# Site content is about cooking and recipies.
#
# URL https://www.simplyrecipes.com/recipes/indian_style_rice/

# %%
import requests

# %%
import os 
from PIL import Image
from IPython.display import IFrame
import pandas as pd
import numpy as np

# %%
url ="https://www.simplyrecipes.com/recipes/indian_style_rice/"
r=requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.27.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
print(r.request.body)
# Out:
# None

# %%
header=r.headers
print(header)
# Out:
# {'Connection': 'keep-alive', 'X-Abt-Application-Version': '5.229.0', 'Strict-Transport-Security': 'max-age=15552000', 'Referrer-Policy': 'no-referrer-when-downgrade', 'X-Content-Type-Options': 'nosniff', 'Content-Security-Policy': "frame-ancestors 'self' *.specless.io *.specless.tech http://*.seo.aws.about.com https://*.seo.aws.about.com http://*.dotdash.com https://*.dotdash.com *.simplyrecipes.com", 'X-Content-Security-Policy': "frame-ancestors 'self' *.specless.io *.specless.tech http://*.seo.aws.about.com https://*.seo.aws.about.com http://*.dotdash.com https://*.dotdash.com *.simplyrecipes.com", 'Set-Cookie': 'TMog=n6857e0d394d74599860f13622cc6b33108; Path=/; Domain=.simplyrecipes.com; Expires=Sun, 15-Apr-2091 12:03:32 GMT; Max-Age=2147483647, globalTI_SID=f05abb26-113e-434a-9731-cd7914025c21; Path=/; Domain=.simplyrecipes.com; Expires=Thu, 27-Mar-2025 08:49:25 GMT; Max-Age=63072000, Mint=n6857e0d394d74599860f13622cc6b33108; Path=/; Domain=.simplyrecipes.com; Expires=Tue, 28-Mar
# ...

# %%
arr=np.array(header)
arr
# Out:
# array(['Connection', 'X-Abt-Application-Version',
#        'Strict-Transport-Security', 'Referrer-Policy',
#        'X-Content-Type-Options', 'Content-Security-Policy',
#        'X-Content-Security-Policy', 'Set-Cookie', 'Expires',
#        'Content-Type', 'Cache-Control', 'Link', 'Content-Encoding', 'Via',
#        'Accept-Ranges', 'NEL', 'Report-To', 'Date', 'X-Served-By',
#        'X-Cache', 'X-Cache-Hits', 'transfer-encoding'], dtype='<U25')

# %%
header["X-Served-By"]
# Out:
# 'cache-bfi-kbfi7400056-BFI, cache-hkg17927-HKG'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text[0:1000]
# Out:
# '<!DOCTYPE html>\n<html id="structuredProjectTemplate_1-0" class="comp no-js simplyrecipes   structuredProjectTemplate article-html html mntl-html" data-ab="99,66,58,99,99,65,99,34" data-resource-version="5.229.0" lang="en" data-lazy-threshold="100" data-simplyrecipes-resource-version="5.229.0" data-mantle-resource-version="3.14.29" data-lifestyle-food-resource-version="5.229.0" data-tracking-container="true">\t\t\t\t\n<!--\n<globe-environment environment="k8s-prod" application="simplyrecipes" dataCenter="us-west-1"/>\n-->\n<head class="loc head">\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t<script type="text/javascript">var Mntl = window.Mntl || {};</script>\n\t\t\t\t\t\n\t\t\t\t\t    <link rel="preconnect" href="//js-sec.indexww.com">\n    <link rel="preconnect" href="//c.amazon-adsystem.com">\n    <link rel="preconnect" href="//securepubads.g.doubleclick.net">\n\n\t\t\t\t\t\n\t\t\t\t\t\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<meta name="robots" content
# ...

# %% [markdown]
# Picture Scraping

# %%
url1="https://www.simplyrecipes.com/thmb/URRJMtQkx5IHKEol9xN37V3v1po=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/__opt__aboutcom__coeus__resources__content_migration__simply_recipes__uploads__2010__06__indian-rice-horiz-a-1600-817049c9784e4943957947e1022b7564.jpg"

# %%
r=requests.get(url1)

# %%
print(r.headers)
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '95946', 'Last-Modified': 'Thu, 13 Oct 2022 20:35:50 GMT', 'ETag': '"b9c1a3101986697b62fe0d6fa014399e"', 'Content-Type': 'image/webp', 'Server': 'AmazonS3', 'cache-control': 'max-age=31536000,public,no-transform', 'Via': '1.1 varnish, 1.1 varnish', 'NEL': '{"report_to":"network-errors","max_age":2592000,"success_fraction":0,"failure_fraction":1.0, "include_subdomains": true}', 'Report-To': '{"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://r.3gl.net/hawklogserver/5462/re.p"}]}', 'Accept-Ranges': 'bytes', 'Date': 'Tue, 28 Mar 2023 08:51:42 GMT', 'Age': '1110992', 'X-Served-By': 'cache-bfi-krnt7300093-BFI, cache-hkg17920-HKG', 'X-Cache': 'HIT, MISS', 'X-Cache-Hits': '123, 0'}

# %%
pic_header=r.headers
arr=np.array(pic_header)
arr
# Out:
# array(['Connection', 'Content-Length', 'Last-Modified', 'ETag',
#        'Content-Type', 'Server', 'cache-control', 'Via', 'NEL',
#        'Report-To', 'Accept-Ranges', 'Date', 'Age', 'X-Served-By',
#        'X-Cache', 'X-Cache-Hits'], dtype='<U14')

# %%
pic_header["Last-Modified"]
# Out:
# 'Thu, 13 Oct 2022 20:35:50 GMT'

# %%
path=os.path.join(os.getcwd(),"Indian Style Rice")
path
# Out:
# '/content/Indian Style Rice'

# %%
with open(path,'wb') as f:
    f.write(r.content)

# %%
Image.open(path)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1500x1000 at 0x7FF0E85CE700>
